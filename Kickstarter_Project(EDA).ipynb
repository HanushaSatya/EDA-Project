# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\pamah\Downloads\Kickstarter+Projects\kickstarter_projects.csv")  #reading dataset file

# %%
df
# Out:
#                 ID                                               Name  \
# 0       1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1        709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2       1703704063                                drawing for dollars
# 3           727286                       Offline Wikipedia iPhone app
# 4       1622952265                                         Pantshirts
# ...            ...                                                ...
# 374848  1486845240                  Americas Got Talent - Serious MAK
# 374849   974738310  EVO Planner: The World's First Personalized Fl...
# 374850  2106246194    Help save La Gattara, Arizona's first Cat Cafe!
# 374851  1830173355                                Digital Dagger Coin
# 374852  1339173863                              Spirits of the Forest
#
#             Category     Subcategory        Country          Launched  \
# ...

# %% [markdown]
# # Data Description and Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374853 entries, 0 to 374852
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ID           374853 non-null  int64
#  1   Name         374853 non-null  object
#  2   Category     374853 non-null  object
#  3   Subcategory  374853 non-null  object
#  4   Country      374853 non-null  object
#  5   Launched     374853 non-null  object
#  6   Deadline     374853 non-null  object
#  7   Goal         374853 non-null  int64
#  8   Pledged      374853 non-null  int64
#  9   Backers      374853 non-null  int64
#  10  State        374853 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 31.5+ MB

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Category       0
# Subcategory    0
# Country        0
# Launched       0
# Deadline       0
# Goal           0
# Pledged        0
# Backers        0
# State          0
# dtype: int64

# %%
df.describe()
# Out:
#                  ID          Goal       Pledged        Backers
# count  3.748530e+05  3.748530e+05  3.748530e+05  374853.000000
# mean   1.074656e+09  4.586378e+04  9.121073e+03     106.690359
# std    6.191377e+08  1.158778e+06  9.132054e+04     911.718520
# min    5.971000e+03  0.000000e+00  0.000000e+00       0.000000
# 25%    5.380728e+08  2.000000e+03  3.100000e+01       2.000000
# 50%    1.075300e+09  5.500000e+03  6.250000e+02      12.000000
# 75%    1.610149e+09  1.600000e+04  4.051000e+03      57.000000
# max    2.147476e+09  1.663614e+08  2.033899e+07  219382.000000

# %%
df.describe()
# Out:
#                  ID          Goal       Pledged        Backers
# count  3.748530e+05  3.748530e+05  3.748530e+05  374853.000000
# mean   1.074656e+09  4.586378e+04  9.121073e+03     106.690359
# std    6.191377e+08  1.158778e+06  9.132054e+04     911.718520
# min    5.971000e+03  0.000000e+00  0.000000e+00       0.000000
# 25%    5.380728e+08  2.000000e+03  3.100000e+01       2.000000
# 50%    1.075300e+09  5.500000e+03  6.250000e+02      12.000000
# 75%    1.610149e+09  1.600000e+04  4.051000e+03      57.000000
# max    2.147476e+09  1.663614e+08  2.033899e+07  219382.000000

# %%
df.shape
# Out:
# (374853, 11)

# %%
df.head(4)
# Out:
#            ID                                               Name  \
# 0  1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1   709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2  1703704063                                drawing for dollars
# 3      727286                       Offline Wikipedia iPhone app
#
#        Category   Subcategory        Country          Launched    Deadline  \
# 0       Fashion       Fashion  United States  21-04-2009 21:02  31-05-2009
# 1  Film & Video        Shorts  United States  23-04-2009 00:07  20-07-2009
# 2           Art  Illustration  United States  24-04-2009 21:52  03-05-2009
# 3    Technology      Software  United States  25-04-2009 17:36  14-07-2009
#
#     Goal  Pledged  Backers       State
# 0   1000      625       30      Failed
# 1  80000       22        3      Failed
# 2     20       35        3  Successful
# 3     99      145       25  Successful

# %% [markdown]
# # Date and time convertions

# %%
df["Launched"] = pd.to_datetime(df["Launched"] ,format = "%d-%m-%Y %M:%S")

# %%
df["Deadline"] = pd.to_datetime(df["Deadline"] , format = '%d-%M-%Y')

# %% [markdown]
# # Filtering the data

# %%
df["Duration"] = df["Launched"] - df["Deadline"]

# %%
df.head()
# Out:
#            ID                                               Name  \
# 0  1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1   709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2  1703704063                                drawing for dollars
# 3      727286                       Offline Wikipedia iPhone app
# 4  1622952265                                         Pantshirts
#
#        Category   Subcategory        Country            Launched  \
# 0       Fashion       Fashion  United States 2009-04-21 00:21:02
# 1  Film & Video        Shorts  United States 2009-04-23 00:00:07
# 2           Art  Illustration  United States 2009-04-24 00:21:52
# 3    Technology      Software  United States 2009-04-25 00:17:36
# 4       Fashion       Fashion  United States 2009-04-27 00:14:10
#
#              Deadline   Goal  Pledged  Backers       State          Duration
# 0 2009-01-31 00:05:00   1000      625       30      Failed  80 days 00:16:02
# ...

# %%
data=df.sample(1000)

# %%
data.reset_index( drop=True, inplace=True )

# %%
data
# Out:
#              ID                                               Name  \
# 0     622191388                       A Studio Album by David Moss
# 1    1121178574                                  Art for El Garden
# 2     302575171                                    Fashion Her Way
# 3    1601885510           In Back of the Yards: A Documentary Film
# 4    1519045716  The Cuba Photographic Exploration: Behind the ...
# ..          ...                                                ...
# 995   967436763          Collaborate with me to make holiday cards
# 996   993654422                  The Perfect Athletic Pants by LTM
# 997    64145736   "Olsen Family Farm" Hand-Crafted Goats Milk Soap
# 998   549871048                 100 5e NPCs - Limitless Adventures
# 999  1259368794                                     D*Cember Reign
#
#          Category     Subcategory        Country            Launched  \
# 0           Music      Indie Rock  United States 2013-03-06 00:17:54
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1000 non-null   int64
#  1   Name         1000 non-null   object
#  2   Category     1000 non-null   object
#  3   Subcategory  1000 non-null   object
#  4   Country      1000 non-null   object
#  5   Launched     1000 non-null   datetime64[ns]
#  6   Deadline     1000 non-null   datetime64[ns]
#  7   Goal         1000 non-null   int64
#  8   Pledged      1000 non-null   int64
#  9   Backers      1000 non-null   int64
#  10  State        1000 non-null   object
#  11  Duration     1000 non-null   timedelta64[ns]
# dtypes: datetime64[ns](2), int64(4), object(5), timedelta64[ns](1)
# memory usage: 93.9+ KB

# %%
data["Deadline"].min()
# Out:
# Timestamp('2009-01-03 00:10:00')

# %%
data["Deadline"].max()
# Out:
# Timestamp('2018-01-30 00:01:00')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1000 non-null   int64
#  1   Name         1000 non-null   object
#  2   Category     1000 non-null   object
#  3   Subcategory  1000 non-null   object
#  4   Country      1000 non-null   object
#  5   Launched     1000 non-null   datetime64[ns]
#  6   Deadline     1000 non-null   datetime64[ns]
#  7   Goal         1000 non-null   int64
#  8   Pledged      1000 non-null   int64
#  9   Backers      1000 non-null   int64
#  10  State        1000 non-null   object
#  11  Duration     1000 non-null   timedelta64[ns]
# dtypes: datetime64[ns](2), int64(4), object(5), timedelta64[ns](1)
# memory usage: 93.9+ KB

# %%
for column in data.columns:
    unique_values = data[column].unique()
    print(f"Unique values in column '{column}': {unique_values}")
    print()
# Out:
# Unique values in column 'ID': [ 622191388 1121178574  302575171 1601885510 1519045716  696117042
#  1624203373 1762432986  624560862  591937907  530619633 1168682192
#  1324255942   80736497  113971735 1499719990 1538304746 1137254110
#  1075207722 1730844349  832167634  925996788  387947286  861012428
#  1612645292  591582289 1478716140 1379688364 1805506062 1561944020
#   709152684 1579411239 1690715211 1063417003 1653526713 1200584325
#   489485038 1118510397 1351831075  447874935  291496014 1399595294
#     5564448 1079564135 1513135704  828864582 1720459568  512567606
#   820257143  727885382 1932424968  994232784  853595202 1101166398
#   980603709  924515518 1289221124 1226784957  851177699 1874684696
#  1051414074  109063835   12106319 1017331826   88534223 1424361904
#  1322675376 1851036239  386872809  530869221 1965674438  401977371
#  1206283107 1864428390  840153745  488852207 1125854728  469550290
#  2046426509 1989826989  870862932 2034119310  370446494 1565432979
# ...

# %%
print(df.nunique())                       #gives count of unique values in each column
# Out:
# ID             374853
# Name           372020
# Category           15
# Subcategory       159
# Country            22
# Launched       343929
# Deadline         3164
# Goal            27692
# Pledged         39989
# Backers          3963
# State               5
# Duration       164888
# dtype: int64

# %% [markdown]
# # Count of projects per main category

# %%
category_counts = data['Category'].value_counts()
# Plot
category_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Projects by Category')
plt.xlabel('Category')
plt.ylabel('Number of Projects')
plt.xticks(rotation='vertical')
plt.tight_layout()
plt.show()

# %%
grby=data.groupby(["Category","Subcategory"])

# %%
grby

# %%
grby["State"].value_counts()
# Out:
# Category  Subcategory     State
# Art       Art             Failed         6
#                           Successful     5
#                           Canceled       2
#           Ceramics        Failed         2
#           Conceptual Art  Failed         1
#                                         ..
# Theater   Plays           Failed         1
#           Spaces          Successful     2
#           Theater         Successful    10
#                           Failed         9
#                           Live           1
# Name: count, Length: 259, dtype: int64

# %% [markdown]
# # Top 10 subcategory

# %%
category_counts = data['Subcategory'].value_counts().nlargest(10)
# Plot
category_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Projects by Category')
plt.xlabel('Category')
plt.ylabel('Number of Projects')
plt.xticks(rotation='vertical')
plt.tight_layout()
plt.show()

# %%
top_subcats = data['Subcategory'].value_counts().nlargest(10)

top_subcats.plot(kind='barh', color='orange')
plt.title('Top 10 Most Common Subcategories')
plt.xlabel('Number of Projects')
plt.ylabel('Subcategory')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Create a pivot table
cat_state_pivot = pd.crosstab(data['Category'], data['State'], normalize='index')

# Plot heatmap
sns.heatmap(cat_state_pivot,annot=True, fmt=".2f")
plt.title('Project Outcomes by Category (Normalized)')
plt.xlabel('Project State')
plt.ylabel('Category')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,8))
category=data["Category"].value_counts()
plt.pie(category.values,labels=category.index,autopct="1%.1f%%")
plt.title("Category Distribution")
# Out:
# Text(0.5, 1.0, 'Category Distribution')

# %% [markdown]
# # Success Rate Distribution

# %%
category_counts = df['State'].value_counts()

# Create the pie chart
plt.figure(figsize=(15,8))
category_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90)

# Add title and labels
plt.title('Success Rate Distribution')
plt.ylabel('')  # Hide the y-axis label

# Show the plot
plt.show()

# %%
country_counts = df['Country'].value_counts().nlargest(10)
# Plot
country_counts.plot(kind='bar', color='orange')
plt.title('Number of Projects by Countries')
plt.xlabel('Country')
plt.ylabel('Number of Projects')
plt.xticks(rotation='vertical')
plt.tight_layout()
plt.show()

# %%
data
# Out:
#              ID                                               Name  \
# 0     622191388                       A Studio Album by David Moss
# 1    1121178574                                  Art for El Garden
# 2     302575171                                    Fashion Her Way
# 3    1601885510           In Back of the Yards: A Documentary Film
# 4    1519045716  The Cuba Photographic Exploration: Behind the ...
# ..          ...                                                ...
# 995   967436763          Collaborate with me to make holiday cards
# 996   993654422                  The Perfect Athletic Pants by LTM
# 997    64145736   "Olsen Family Farm" Hand-Crafted Goats Milk Soap
# 998   549871048                 100 5e NPCs - Limitless Adventures
# 999  1259368794                                     D*Cember Reign
#
#          Category     Subcategory        Country            Launched  \
# 0           Music      Indie Rock  United States 2013-03-06 00:17:54
# ...

# %%
country_count = data['Country'].value_counts()
sns.set(style="darkgrid")
sns.barplot(x = country_count.index, y = country_count.values ,alpha=0.9)
plt.title('Kickstarter Distribution of Countries')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xticks(rotation=90, horizontalalignment="center")
plt.xlabel('Country', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data['Goal'], bins=100, color='skyblue', log_scale=True)
plt.title('Distribution of Project Funding Goals (Log Scale)')
plt.xlabel('Funding Goal')
plt.ylabel('Number of Projects')
plt.tight_layout()
plt.show()

# %%
#  Step 10: Pledged Amount Distribution (Only for Successful Projects)
plt.figure(figsize=(10,6))
sns.histplot(data[data['State'] == 'Successful']['Pledged'], bins=100, color='green', log_scale=True)
plt.title('Distribution of Pledged Amounts (Successful Projects, Log Scale)')
plt.xlabel('Pledged Amount')
plt.ylabel('Number of Projects')
plt.tight_layout()
plt.show()

# %%
# Step 11: Goal vs Pledged (Scatter Plot)
sns.scatterplot(data=data[data['Pledged'] < 1000000], x='Goal', y='Pledged', hue='State', alpha=0.6)
plt.title('Goal vs Pledged Amount (Zoomed In)')
plt.xlabel('Goal Amount')
plt.ylabel('Pledged Amount')
plt.legend(title='Project State')
plt.tight_layout()
plt.show()

# %%
# Step 12: Average Backers per Category
data['Backers'] = pd.to_numeric(data['Backers'], errors='coerce')

avg_backers = data.groupby('Category')['Backers'].mean().sort_values(ascending=False)

avg_backers.plot(kind='bar', color='salmon')
plt.title('Average Number of Backers per Category')
plt.xlabel('Category')
plt.ylabel('Average Backers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Step 12: Success Rate by Goal Range
data['goal_range'] = pd.cut(data['Goal'], bins=[0, 1000, 5000, 10000, 20000, 50000, 100000, 500000, 1e6, 1e7],
                          labels=['<1k','1k–5k','5k–10k','10k–20k','20k–50k','50k–100k','100k–500k','500k–1M','1M+'])

goal_success_rate = (
    data[data['State'] == 'Successful'].groupby('goal_range').size()
    / data.groupby('goal_range').size()
)

goal_success_rate.plot(kind='bar', color='teal')
plt.title('Success Rate by Goal Range')
plt.xlabel('Goal Range (USD)')
plt.ylabel('Success Rate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\pamah\AppData\Local\Temp\ipykernel_11104\187021808.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data[data['State'] == 'Successful'].groupby('goal_range').size()
# C:\Users\pamah\AppData\Local\Temp\ipykernel_11104\187021808.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   / data.groupby('goal_range').size()

# %%
#  Step 13: Number of Backers Distribution (Log Scale)
plt.figure(figsize=(12,7))
sns.histplot(data['Backers'], bins=100, color='orchid', log_scale=True)
plt.title('Distribution of Number of Backers (Log Scale)')
plt.xlabel('Backers')
plt.ylabel('Number of Projects')
plt.tight_layout()
plt.show()

# %%
# Step 14: Average Pledge per Backer (Only Successful Projects)
df_success = data[(data['State'] == 'Successful') & (data['Backers'] > 0)]
df_success['avg_pledge_per_backer'] = df_success['Pledged'] / df_success['Backers']

sns.histplot(df_success['avg_pledge_per_backer'], bins=100, color='coral')
plt.title('Average Pledge Per Backer (Successful Projects)')
plt.xlabel('Avg Pledge ($)')
plt.ylabel('Number of Projects')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\pamah\AppData\Local\Temp\ipykernel_11104\956863773.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_success['avg_pledge_per_backer'] = df_success['Pledged'] / df_success['Backers']

# %%
# Calculate success rates per category
category_success = df[df['State'] == 'Successful']['Category'].value_counts()
category_total = df['Category'].value_counts()
success_rate = (category_success / category_total).sort_values(ascending=False)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(x=success_rate.index, y=success_rate.values, palette='viridis')
plt.xticks(rotation=45)
plt.title('Success Rate by Project Category')
plt.ylabel('Success Rate')
plt.xlabel('Project Category')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\pamah\AppData\Local\Temp\ipykernel_11104\4043168384.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=success_rate.index, y=success_rate.values, palette='viridis')

# %%
df['goal_bin'] = pd.cut(df['Goal'], bins=[0, 1000, 5000, 10000, 20000, 50000, 100000, float('inf')],
                        labels=['<1k', '1k-5k', '5k-10k', '10k-20k', '20k-50k', '50k-100k', '>100k'])

# Calculate success rates per goal bin
goal_success = df[df['State'] == 'Successful']['goal_bin'].value_counts()
goal_total = df['goal_bin'].value_counts()
goal_success_rate = (goal_success / goal_total).sort_index()

# Plotting
plt.figure(figsize=(10, 5))
sns.lineplot(x=goal_success_rate.index, y=goal_success_rate.values, marker='o')
plt.title('Success Rate by Funding Goal')
plt.ylabel('Success Rate')
plt.xlabel('Funding Goal Range')
plt.tight_layout()
plt.show()

# %%
# Calculate number of successful campaigns per country
country_success = df[df['State'] == 'Successful']['Country'].value_counts().head(10)

# Plotting
plt.figure(figsize=(12, 5))
sns.barplot(x=country_success.index, y=country_success.values, palette='coolwarm')
plt.title('Top 10 Countries by Number of Successful Campaigns')
plt.ylabel('Number of Successful Campaigns')
plt.xlabel('Country')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\pamah\AppData\Local\Temp\ipykernel_11104\1688648005.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_success.index, y=country_success.values, palette='coolwarm')

# %%
# Drop rows with NaT in 'launched' column
df = df.dropna(subset=['Launched'])

# Extract launch month
df['launch_month'] = df['Launched'].dt.month_name()
df.sort_values(by='launch_month',ascending=True,inplace=True)

# Calculate total and successful campaigns per month
monthly_total = df['launch_month'].value_counts().sort_index()
monthly_success = df[df['State'] == 'Successful']['launch_month'].value_counts().sort_index()
monthly_success_rate = (monthly_success / monthly_total).sort_index()

# Plotting
plt.figure(figsize=(12, 6))
sns.lineplot(x=monthly_success_rate.index, y=monthly_success_rate.values, marker='o', color='Skyblue')
plt.title('Monthly Launch Success Rates')
plt.ylabel('Success Rate')
plt.xlabel('Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
